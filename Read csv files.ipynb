# %%
import pandas as pd
url='https://raw.githubusercontent.com/sarwansingh/Python/af0fb4f782d909754270514490bd7734cf8d03c0/ClassExamples/data/titanic.csv'
df2=pd.read_csv(url)
#df2.head()
#df2.tail()
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.count()
#df2.loc[df2.Pclass==1].value_counts().count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df2.loc[df2.Survived==0].value_counts().count() #total peoples which arw not survived
#df2.Survived.count()
# Out:
# 1

# %%
df2.loc[df2.Survived==0,["Survived"]].count() #total peoples are survived
# Out:
# Survived    549
# dtype: int64

# %%
df2['Cabin'].notnull().value_counts()
# Out:
# False    687
# True     204
# Name: Cabin, dtype: int64

# %%
df2.loc[df2.Sex=='male'].value_counts().count()
# Out:
# 95

# %%
df2.loc[df2.Sex=='female'].value_counts().count()
# Out:
# 88

# %%
df2.Sex.count()
# Out:
# 891

# %%
import pandas as pd
url='https://raw.githubusercontent.com/Anmolpreet001/dataset/main/diabetes_prediction_dataset.csv'
df1=pd.read_csv(url)
df1
# df1.count()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
print(df1.shape,df1.columns)
# Out:
# (100000, 9) Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
df1['heart_disease'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df1['bmi'].shape
df1.notnull().value_counts()
df1.isnull().value_counts()
# Out:
# gender  age    hypertension  heart_disease  smoking_history  bmi    HbA1c_level  blood_glucose_level  diabetes
# False   False  False         False          False            False  False        False                False       100000
# dtype: int64

# %%
# how many number of females in the datasets 

df1.loc[df1.gender=='Female'].value_counts().count()
# Out:
# 56161

# %%
#how many number of males in the datasets
df1.loc[df1.gender=='Male'].value_counts().count()
# Out:
# 39967

# %%
# category of gender in the dataset 
df1['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
import matplotlib.pyplot as plt
df1["gender"].value_counts().plot.bar(color="cyan")
plt.show()

# %%
df1.iloc[12669]
# Out:
# gender                       Other
# age                           10.0
# hypertension                     0
# heart_disease                    0
# smoking_history        not current
# bmi                          14.09
# HbA1c_level                    5.0
# blood_glucose_level            140
# diabetes                         0
# Name: 12669, dtype: object

# %%
df1["gender"].value_counts()
# Out:
# Female    58552
# Male      41430
# Other        18
# Name: gender, dtype: int64

# %%
df1['age'].notnull().value_counts()
# Out:
# True    100000
# Name: age, dtype: int64

# %%
df1.head()  #head is used to print first five and any number of rows are printed
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df1.tail() # tail is used to print last five and any number of rows are printed
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
ds=df1.loc[df1.diabetes==1]
ds
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 6      Female  44.0             0              0           never  19.31
# 26       Male  67.0             0              1     not current  27.32
# 38       Male  50.0             1              0         current  27.32
# 40       Male  73.0             0              0          former  25.91
# 53     Female  53.0             0              0          former  27.32
# ...       ...   ...           ...            ...             ...    ...
# 99935  Female  65.0             1              1           never  33.55
# 99938    Male  55.0             0              1          former  30.42
# 99957  Female  61.0             0              0         No Info  34.45
# 99962  Female  58.0             1              0           never  38.31
# 99979  Female  61.0             0              0         current  30.11
#
#        HbA1c_level  blood_glucose_level  diabetes
# 6              6.5                  200         1
# ...

# %%
ds.loc[ds.gender=='Female']
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 6      Female  44.0             0              0           never  19.31
# 53     Female  53.0             0              0          former  27.32
# 59     Female  67.0             0              0           never  63.48
# 87     Female  36.0             0              0         current  32.27
# 94     Female  60.0             0              0           never  27.32
# ...       ...   ...           ...            ...             ...    ...
# 99929  Female  37.0             0              0         No Info  36.87
# 99935  Female  65.0             1              1           never  33.55
# 99957  Female  61.0             0              0         No Info  34.45
# 99962  Female  58.0             1              0           never  38.31
# 99979  Female  61.0             0              0         current  30.11
#
#        HbA1c_level  blood_glucose_level  diabetes
# 6              6.5                  200         1
# ...

# %%
ds.loc[ds.gender=='Male']
# Out:
#       gender   age  hypertension  heart_disease smoking_history    bmi  \
# 26      Male  67.0             0              1     not current  27.32
# 38      Male  50.0             1              0         current  27.32
# 40      Male  73.0             0              0          former  25.91
# 55      Male  50.0             0              0          former  37.16
# 81      Male  57.0             0              0         No Info  27.32
# ...      ...   ...           ...            ...             ...    ...
# 99826   Male  63.0             0              1         No Info  27.32
# 99829   Male  58.0             0              0          former  32.38
# 99867   Male  64.0             1              0          former  33.12
# 99897   Male  67.0             0              0         current  27.32
# 99938   Male  55.0             0              1          former  30.42
#
#        HbA1c_level  blood_glucose_level  diabetes
# 26             6.5                  200         1
# ...

# %%
ds.loc[ds.gender=='Other']
# Out:
# Empty DataFrame
# Columns: [gender, age, hypertension, heart_disease, smoking_history, bmi, HbA1c_level, blood_glucose_level, diabetes]
# Index: []

# %%
df1.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
df1.loc[df1.diabetes==0]
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df1['diabetes'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df1['diabetes'].notnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 99995    True
# 99996    True
# 99997    True
# 99998    True
# 99999    True
# Name: diabetes, Length: 100000, dtype: bool

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1.groupby('', sort=True)['song_name'].count() .plot()
# Out:
#   Cell In[94], line 1
#     df1.loc(df1.['age']['diabetes']).count().plot(kind='line')
#                 ^
# SyntaxError: invalid syntax
